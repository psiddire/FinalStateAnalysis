# %%
import os
from sys import argv, stdout, stderr
from ROOT import TCanvas, TLegend, gROOT, gStyle, TFile, TIter, gSystem, TTree, TH1F, TPaveStats, TGraph, TH2F, TProfile
import sys
gROOT.SetStyle()
gROOT.SetBatch(True)
from array import array
# Out:
# Welcome to JupyROOT 6.12/07

# %%
f = TFile('ntuplize.root')
f1 = TFile('ntuplizeHTT.root')
t = f.Get('em/final/Ntuple')
t1 = f1.Get('em/final/Ntuple')

# %%
a = []
for entry in t:
    a.append(entry.evt)
print(len(a))
# Out:
# 2284

# %%
e = []
e1 = []
            
def inner():
    for entry1 in t1:
        if entry1.evt==entry.evt:
            e.append(entry.ePt)
            e1.append(entry1.ePt)
            return

for entry in t:
    print "Next"
    inner()
# Out:
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# Next
# ...

# %%
canvas = TCanvas("canvas","canvas",800,800)
legend = TLegend(0.62,0.6,0.9,0.7)
h = TH1F("h","",40,0,400)
h1 = TH1F("h1","",40,0,400)
h1.GetXaxis().SetTitle("e Pt (GeV)")
h1.SetLineColor(2)
                                   
for i in e:
    h.Fill(i)
                                       
for j in e1:
    h1.Fill(j)
                                   
h1.Draw()
h.Draw("SAME")
legend.AddEntry("h", "isLFV=1")
legend.AddEntry("h1", "isLFV=0")
legend.Draw()
canvas.Draw()

# %%
m = []
m1 = []
            
def inner():
    for entry1 in t1:
        if entry1.evt==entry.evt:
            m.append(entry.mPt)
            m1.append(entry1.mPt)
            return

for entry in t:
    inner()

# %%
canvas = TCanvas("canvas","canvas",800,800)
legend = TLegend(0.62,0.6,0.9,0.7)
h = TH1F("h","",40,0,400)
h1 = TH1F("h1","",40,0,400)
h.GetXaxis().SetTitle("m Pt (GeV)")
h1.SetLineColor(2)
                                   
for i in m:
    h.Fill(i)
                                       
for j in m1:
    h1.Fill(j)
                                   
h.Draw()
h1.Draw("SAME")
legend.AddEntry("h", "isLFV=1")
legend.AddEntry("h1", "isLFV=0")
legend.Draw()
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TFile::Append>: Replacing existing TH1: h (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h1 (Potential memory leak).

# %%
f = TFile('/hdfs/store/user/psiddire/MCApril1/WW_TuneCP5_13TeV-pythia8_v2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1/make_ntuples_cfg-C6F6246D-B444-E811-9EB9-0CC47A4D76C0.root')
f1 = TFile('/hdfs/store/user/caillol/SMHTT_2017_29nov/WW_TuneCP5_13TeV-pythia8__94X_mc2017_realistic_v14-v1/make_ntuples_cfg-C6F6246D-B444-E811-9EB9-0CC47A4D76C0.root')
t = f.Get('em/final/Ntuple')
t1 = f1.Get('em/final/Ntuple')
# Out:
# Warning in <TClass::Init>: no dictionary for class ROOT::TIOFeatures is available

# %%
e = []
e1 = []
            
def inner():
    for entry1 in t1:
        if entry1.evt==entry.evt:
            e.append(entry.ePt)
            e1.append(entry1.ePt)
            return

for entry in t:
    inner()

# %%
canvas = TCanvas("canvas","canvas",800,800)
legend = TLegend(0.62,0.6,0.9,0.7)
h = TH1F("h","",40,0,400)
h1 = TH1F("h1","",40,0,400)
h1.GetXaxis().SetTitle("e Pt (GeV)")
h1.SetLineColor(2)
                                   
for i in e:
    h.Fill(i)
                                       
for j in e1:
    h1.Fill(j)
                                   
h1.Draw()
h.Draw("SAME")
legend.AddEntry("h", "isLFV=1")
legend.AddEntry("h1", "isLFV=0")
legend.Draw()
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
